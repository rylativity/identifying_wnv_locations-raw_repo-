# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import Imputer
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import precision_score, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
train_df = pd.read_csv('./kaggle_data/train.csv')
weather_df = pd.read_csv('./kaggle_data/weather.csv')
spray_df = pd.read_csv('./kaggle_data/spray.csv')

# %%
train_df.head()
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 2   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279                9
# 3    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
# 4    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
#
#    NumMosquitos  WnvPresent
# 0             1           0
# 1             1           0
# 2             1           0
# 3             1           0
# 4             4           0

# %%
weather_df.head()
# Out:
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        1  2007-05-01    83    50   67     14        51      56    0    2
# 1        2  2007-05-01    84    52   68      M        51      57    0    3
# 2        1  2007-05-02    59    42   51     -3        42      47   14    0
# 3        2  2007-05-02    60    43   52      M        42      47   13    0
# 4        1  2007-05-03    66    46   56      2        40      48    9    0
#
#      ...    CodeSum Depth Water1 SnowFall PrecipTotal StnPressure SeaLevel  \
# 0    ...                0      M      0.0        0.00       29.10    29.82
# 1    ...                M      M        M        0.00       29.18    29.82
# 2    ...         BR     0      M      0.0        0.00       29.38    30.09
# 3    ...      BR HZ     M      M        M        0.00       29.44    30.08
# 4    ...                0      M      0.0        0.00       29.39    30.12
#
#   ResultSpeed ResultDir  AvgSpeed
# 0         1.7        27       9.2
# 1         2.7        25       9.6
# 2        13.0         4      13.4
# 3        13.3         2      13.4
# 4        11.7         7      11.9
#
# [5 rows x 22 columns]

# %% [markdown]
# Need to better understand `spray_df` and identify where weather stations 1 and 2 are.  All dataframes include date data, so the next step is to figure out how to appropriately combine them.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#sns.heatmap(train_df.corr(), annot=True)

# %% [markdown]
# Unsurprisingly, the likelihood of WNV increases as the number of mosquitos increase.

# %%
#print(train_df.shape)
#train_df.isnull().sum()

# %%
#print(spray_df.shape)
#spray_df.isnull().sum()
                 ## We will need to deal with these time nulls, but it may make sense to drop the time column
                  # since the other dfs dont have time

# %%
#print(spray_df.shape)
#weather_df.isnull().sum()

# %%
spray_df.drop('Time', axis = 1, inplace = True) # dropping time from spray data because it is not in any other dfs

# %%
#spray_df.head()

# %%
daily_weather = weather_df[weather_df['Station'] == 1] # creating weather data df using only one station

# %%
daily_weather.drop('Station', axis= 1, inplace=True) # dropping station label since all are station 1
# Out:
# /home/ryan/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
daily_weather.reset_index(inplace=True, drop=True) 

daily_weather['Date'] = pd.to_datetime(daily_weather['Date']) 

daily_weather.set_index('Date',inplace=True, drop=True) # datetime index on weather data
# Out:
# /home/ryan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
train_df['Date'] = pd.to_datetime(train_df['Date']) #datetime index on training data

train_df.set_index('Date', inplace=True, drop=True)

# %%
new_df = pd.merge(train_df, 
                  daily_weather, 
                  left_on = train_df.index, right_on = daily_weather.index) #new_df = combined weather and train data

# %%
#new_df.shape, train_df.shape, weather_df.shape

# %%
new_df['key_0'] = pd.to_datetime(new_df['key_0'])

new_df.set_index('key_0', inplace=True, drop=True)

new_df.index.rename('Date', inplace=True) #assiging date as index of new_df

# %%
new_df.drop(['Water1','SnowFall'], axis=1, inplace=True) # dropping these columns since they provided no info

# %%
mode_precip = float(new_df[new_df['PrecipTotal'] != '  T'].StnPressure.mode()[0]) # storing mode precip value for replacement in next step

# %%
precip_totals = []
for total in new_df.PrecipTotal:
    if total == '  T':
        precip_totals.append(mode_precip)
    else:
        precip_totals.append(total)

new_df.PrecipTotal = pd.to_numeric(precip_totals) # replacing '  T' with mode precip value

# %%
mode_pressure = new_df[new_df['StnPressure'] != 'M'].StnPressure.mode() # storing mode pressure for replacement in next step

# %%
pressures = []
for pressure in new_df.StnPressure:
    if pressure == 'M':
        pressures.append(mode_pressure)
    else:
        pressures.append(pressure)
pressures = [float(pressure) for pressure in pressures]

new_df.StnPressure = pd.to_numeric(pressures) # replacing 'M' with mode pressure value

# %%
pressures = [float(pressure) for pressure in pressures] # converting strings to floats

# %%
#new_df.dtypes
cols_to_change = ['Tavg',
                 'Depart',
                 'Cool',
                 'Sunrise',
                 'Sunset',
                 'Depth',
                 'PrecipTotal',
                 'StnPressure',
                 'SeaLevel',
                 'AvgSpeed'
                 ] # columns of type object that can be coerced to numeric values

# %%
for col in cols_to_change:
    new_df[col] = pd.to_numeric(new_df[col])#changing columns above to numeric

# %%
wnv1_df = new_df[new_df['WnvPresent'] == 1]

# %%
wnv0_df = new_df[new_df['WnvPresent'] == 0].sample(n = wnv1_df.shape[0], random_state = 42)

# %%
df = pd.concat([wnv1_df, wnv0_df], axis = 0)

# %%
num_df = df._get_numeric_data()

# %%
X = num_df.drop('WnvPresent', axis = 1)
y = num_df.WnvPresent

# %%
pca = PCA()

# %%
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
X = pca.transform(X)

# %%
pd.DataFrame(X)
# Out:
#               0          1          2          3          4          5   \
# 0     -80.519488  -7.382664  26.328095  10.664443  -0.256757   5.176406
# 1     -72.005400 -32.542486  20.996292   4.412615  15.060290  20.259953
# 2     -72.005400 -32.542486  20.996292   4.412615  15.060290  20.259953
# 3     -72.005400 -32.542486  20.996292   4.412615  15.060290  20.259953
# 4     -72.005400 -32.542486  20.996292   4.412615  15.060290  20.259953
# 5     -72.005400 -32.542486  20.996292   4.412615  15.060290  20.259953
# 6     -62.663771  -5.119786  30.530151   7.712171  -9.125570  -3.013748
# 7     -62.219918   2.835747   7.038321  -7.120608  -9.574042  -5.060828
# 8     -62.082364  43.581318   4.776360 -12.764716 -10.071664  -5.765327
# 9     -62.349285 -18.656551  11.429531  -2.252203  -9.271891  -4.423002
# 10    -62.073793 -13.718596  -3.151639 -11.458751  -9.550273  -5.693581
# 11    -62.073633 -24.780944  -4.638081 -11.171154  -9.442883  -5.676937
# 12    -62.666177  -4.177560  30.824773   7.779281  -9.137624  -3.000542
# 13    -62.053966   6.795589  -1.577752 -12.679725  -9.756207  -5.824100
# 14    -61.940456  11.876466  -7.228048 -16.571402  -9.893575  -6.357550
# 15    -62.745994  22.636989  38.685130   9.649929  -9.312106  -2.691174
# 16    -62.028877  -1.803684  -4.122022 -13.281394  -9.692691  -5.926296
# 17    -62.358228  11.443691  15.802188  -2.805303  -9.536446  -4.444460
# 18    -62.094628   4.073054   0.276725 -11.279311  -9.691227  -5.636773
# 19    -61.969518  16.373005  -4.998639 -15.725518  -9.915958  -6.229190
# 20    -62.053853 -25.522373  -5.676522 -11.748112  -9.474930  -5.749728
# 21    -62.577065 -33.892464  22.146854   5.708840  -8.955544  -3.338605
# 22    -62.577065 -33.892464  22.146854   5.708840  -8.955544  -3.338605
# 23    -62.577065 -33.892464  22.146854   5.708840  -8.955544  -3.338605
# 24    -60.399726 -12.148726  -7.107016 -17.941691  -2.626394   0.826507
# 25    -60.991997 -34.925652  22.770626   2.227954  -1.932468   3.593919
# 26    -61.039153  -8.490722  28.703608   3.008069  -2.119695   3.746253
# 27    -53.226392  37.238857  25.339604  -9.678715  -4.751011   3.785693
# 28    -53.018343  26.856676  12.491986 -16.240423  -4.831084   2.853505
# 29    -53.232617  23.016073  23.832869  -9.079771  -4.614580   3.841751
# ...          ...        ...        ...        ...        ...        ...
# 1072   74.809971  43.690327  -2.100241  -7.476155  10.120837  -4.348010
# 1073  149.271176  -5.506591 -22.754964   4.738912 -11.608956   7.018203
# 1074  -52.842445  38.094371   4.197840 -22.355429  -5.077681   2.022441
# 1075  -84.699584  -5.047582  11.199061  28.385686   1.122734  -6.212518
# 1076   39.736883  29.230416 -12.601799   3.939461   7.876925 -18.025887
# 1077  127.573117  27.252778 -22.043102  26.900437  10.577477   8.967367
# 1078  133.446675  -9.221037 -23.457998  16.424249 -10.304416   1.498776
# 1079  -69.224939 -23.153743 -15.451037  -4.545041   3.502452  -2.169956
# 1080   33.537467  13.771772  -5.359917 -16.401323   5.168100  -7.982587
# 1081  -89.241001  -5.992831 -24.465600  -4.453651   5.770955   3.511609
# 1082  -80.054409 -18.117996 -32.448917  10.558030  16.581617  -2.619353
# 1083  -67.042802  26.659152  -4.877374 -13.862465 -10.887589  -8.227357
# 1084   70.346855 -15.217276 -13.029762 -17.985938  24.988724  14.495502
# 1085  149.330645 -19.647773 -27.730348   3.226497 -11.550988   6.789727
# 1086  -67.032170  17.755861  -6.584843 -13.952050 -10.819916  -8.254727
# 1087  133.405818  26.333074 -16.574924  16.783857 -10.597895   1.616922
# 1088  -86.262976  -2.928451  18.339034  27.563975  -0.535447  -4.707713
# 1089  -56.694508  29.375425  18.609679  -2.402504   6.537668   9.357303
# 1090  -62.579900 -32.935330  22.428080   5.775683  -8.961976  -3.327482
# 1091  -11.957822  -1.970927 -25.766307   4.444909  -9.305395   8.883929
# 1092  -72.444082   3.545292 -14.683907  -1.289260   4.944266  -2.279111
# 1093  -79.567784  23.136636  38.373272  -0.209634  -6.993146   8.486017
# 1094   69.967405 -22.476883 -13.619856 -15.991400   2.376664  -5.833611
# 1095  -80.118413  10.058033 -19.190082  -3.540546  -9.139992   6.328966
# 1096   70.370485  -6.751736 -13.197246 -18.985454  24.885027  14.375053
# 1097  -79.697433 -17.912585 -20.355693 -16.067281  -0.871079   1.446273
# 1098  -85.947935  36.679679  -8.993262   8.006865   9.441346   2.062141
# 1099  143.686580 -10.005136 -41.236029  28.630445   2.288362   0.299377
# 1100   26.621158  53.325525  16.965336 -20.264587  12.646581   8.796728
# 1101   26.790720 -20.239351  -1.976187 -23.808465  13.181822   8.163134
#
#              6          7         8         9         10        11        12  \
# 0     -8.464905  -4.102201  1.832009 -2.176076  0.161920  0.121155 -0.632583
# 1      8.397455  -0.519609 -1.755590  5.381624 -0.110147  0.601660  1.969991
# 2      8.397455  -0.519609 -1.755590  5.381624 -0.110147  0.601660  1.969991
# 3      8.397455  -0.519609 -1.755590  5.381624 -0.110147  0.601660  1.969991
# 4      8.397455  -0.519609 -1.755590  5.381624 -0.110147  0.601660  1.969991
# 5      8.397455  -0.519609 -1.755590  5.381624 -0.110147  0.601660  1.969991
# 6      2.541106   6.506557 -2.867175  3.384467  0.940029  0.571110 -1.742734
# 7      3.422507   6.477064 -2.589937  3.530159  0.552820  0.792717 -1.335226
# 8      3.851864   6.500456 -2.110087  3.522841  0.460408  1.119896  0.254197
# 9      3.095778   6.447351 -2.845656  3.537594  0.700032  0.823074 -0.694688
# 10     3.642851   6.429022 -2.673648  3.627820  0.459596  0.960327 -0.443423
# 11     3.594007   6.430006 -2.798018  3.631846  0.428773  0.779638 -1.571765
# 12     2.545795   6.493332 -2.843794  3.398248  0.974409  0.723112 -0.733774
# 13     3.761521   6.452652 -2.461396  3.599203  0.440328  1.028777 -0.171695
# 14     3.993260   6.463432 -2.375359  3.614940  0.308899  0.944623 -1.024625
# 15     2.492773   6.548080 -2.628904  3.305970  1.008794  0.614560 -1.453209
# 16     3.770159   6.454418 -2.550499  3.607094  0.387011  0.864873 -1.260093
# 17     3.191417   6.500026 -2.566129  3.466191  0.672914  0.757295 -1.314953
# 18     3.667246   6.467509 -2.521333  3.573934  0.444396  0.854433 -1.221695
# 19     3.960895   6.456894 -2.328898  3.612244  0.365755  1.093931  0.004433
# 20     3.651521   6.368443 -2.737863  3.700374  0.538174  1.379344  2.381321
# 21     2.616466   6.404451 -3.054607  3.527048  0.994702  1.121532  1.916204
# 22     2.616466   6.404451 -3.054607  3.527048  0.994702  1.121532  1.916204
# 23     2.616466   6.404451 -3.054607  3.527048  0.994702  1.121532  1.916204
# 24    -9.511341   1.707510 -2.911480  1.903719  0.797105  1.109313 -0.359128
# 25   -10.718398   1.687611 -3.358092  1.775318  1.409764  1.222666  1.903537
# 26   -10.721730   1.768650 -3.160851  1.667752  1.353931  0.835194 -0.749823
# 27    -8.794909  -2.601410 -0.512018 -2.115326  1.360977  1.289673 -0.125249
# 28    -8.437273  -2.632683 -0.521939 -2.022343  1.180904  1.352695 -0.110938
# 29    -8.862777  -2.618445 -0.655779 -2.092677  1.367832  1.245712 -0.307666
# ...         ...        ...       ...       ...       ...       ...       ...
# 1072 -11.517439   5.478089 -7.778845  2.388067  2.375489 -1.963107  0.011175
# 1073  -0.089405   7.380822 -4.042150 -4.491455  1.772836 -3.087661 -0.466876
# 1074  -8.061869  -2.619537 -0.346116 -1.992445  0.995835  1.318008 -0.822474
# 1075   5.322054   6.690281  0.639501  7.100084 -0.583813 -1.714558 -0.052647
# 1076   9.733948 -10.668998  7.955491 -2.364136 -1.748951 -1.990605 -0.499123
# 1077 -12.964514  -3.996389 -1.066319  3.133290  2.147001  3.582338 -0.121529
# 1078   7.564604   4.285108 -2.406352 -2.679616  0.447508 -1.526839  0.176432
# 1079  -7.059104   0.163919  2.673014 -1.099049 -1.668953  0.219694 -1.204055
# 1080  -5.881525  -7.679015  0.460227  0.857175 -0.083662 -0.305899  0.061980
# 1081 -13.291313   6.555557 -1.362988  1.399119 -0.288403 -0.111348  0.376250
# 1082 -10.857932  -4.335377  4.095925  0.540457 -1.814339 -0.879280 -0.759173
# 1083   8.799266  -1.510680  0.215497  1.032538  0.189371  0.356676 -0.892713
# 1084   3.647931   0.838562  1.048083  0.953882  0.494721 -1.569044 -0.909618
# 1085  -0.008554   7.299182 -4.097152 -4.385393  1.848830 -2.509540  3.343077
# 1086   8.790237  -1.537257  0.146946  1.067781  0.213046  0.485060 -0.003131
# 1087   7.626175   4.332527 -2.072534 -2.757543  0.479155 -1.443238  0.587010
# 1088   4.139566   7.124221 -2.375551  0.274117 -0.197890 -0.707971 -1.187539
# 1089  25.359882  -3.462665 -0.691607 -1.496215 -0.078425 -0.064692 -0.121411
# 1090   2.614832   6.405921 -3.046387  3.524387  0.996969  1.122793  1.925091
# 1091  -3.519805  -0.372274 -0.016811 -2.238972 -4.267814  1.173636  0.095935
# 1092  -6.700020   1.233711  2.194343 -2.114468 -1.988279  0.386927  0.237395
# 1093 -12.024287   3.560283  6.762548 -2.796832 -0.365615  2.080191 -1.584640
# 1094  -6.019474   4.208209  6.372742  1.520186  0.304615 -1.513175 -1.133959
# 1095  -3.787801   9.026499 -1.909593 -1.165343  4.958238 -2.991200 -0.313587
# 1096   3.732134   0.832090  1.156874  0.961592  0.504449 -1.387119  0.191946
# 1097  -6.914874  -4.232256  2.138782 -1.817656 -0.458362  0.901594  2.758658
# 1098 -12.079124   0.252222  3.441230  4.462332 -0.302085 -1.150983  0.789271
# 1099   5.535244  -2.772886  5.375110 -4.205538  2.891164  6.579206 -2.020948
# 1100  16.390462  -2.486855 -1.397911 -1.604642 -0.727965  1.025366  0.221164
# 1101  16.425892  -2.592696 -2.051050 -1.414132 -0.867964  0.888910 -0.578263
#
#             13        14        15        16        17        18            19
# 0    -0.591829  0.224477 -0.260186  0.013968 -0.051246 -0.011990  2.856788e-18
# 1    -0.571982  0.037644 -0.042948 -0.102872  0.007611 -0.005758  3.102279e-17
# 2    -0.571982  0.037644 -0.042948 -0.102872  0.007611 -0.005758  3.102279e-17
# 3    -0.571982  0.037644 -0.042948 -0.102872  0.007611 -0.005758  3.102279e-17
# 4    -0.571982  0.037644 -0.042948 -0.102872  0.007611 -0.005758  3.102279e-17
# 5    -0.571982  0.037644 -0.042948 -0.102872  0.007611 -0.005758  3.102279e-17
# 6    -0.435820  0.006352  0.081306 -0.004090 -0.025592  0.004634  1.078629e-17
# 7    -0.391154 -0.002078  0.086978 -0.013302 -0.008630  0.005760  1.376596e-18
# 8    -0.415500 -0.001762  0.163840 -0.015075  0.014832  0.006010  2.993384e-18
# 9    -0.456782 -0.015083 -0.145686 -0.024191  0.053680  0.003507  7.071717e-18
# 10   -0.429238 -0.021753 -0.107380 -0.028707  0.038037  0.004249 -5.828012e-19
# 11   -0.383832 -0.015031 -0.056367 -0.026034 -0.060673  0.004820 -1.265254e-17
# 12   -0.483074  0.001611 -0.144379 -0.016075  0.098975  0.003206  1.938585e-17
# 13   -0.421466 -0.010018 -0.136556 -0.028781  0.122370  0.004760  6.406969e-18
# 14   -0.361027 -0.002393  0.030550 -0.026162 -0.088979  0.005727 -1.948874e-17
# 15   -0.435610  0.023009  0.103720 -0.003771 -0.074813  0.004567  4.592333e-18
# 16   -0.374172 -0.009530  0.075545 -0.017690  0.001404  0.006116 -2.113177e-18
# 17   -0.400753  0.013775 -0.084963 -0.018744  0.058176  0.005010  4.783160e-18
# 18   -0.376933  0.004161 -0.121718 -0.030671 -0.058635  0.004709 -1.782120e-17
# 19   -0.410535 -0.009456 -0.075358 -0.032490 -0.024250  0.004579 -1.291577e-17
# 20   -0.577242 -0.077025 -0.011629 -0.032603 -0.018317  0.001626  5.376436e-18
# 21   -0.629117 -0.064387 -0.067017 -0.025608 -0.062079 -0.000066  1.107289e-17
# 22   -0.629117 -0.064387 -0.067017 -0.025608 -0.062079 -0.000066  1.107289e-17
# 23   -0.629117 -0.064387 -0.067017 -0.025608 -0.062079 -0.000066  1.107289e-17
# 24   -1.004349 -0.115597 -0.110892 -0.138297  0.055319  0.003207  5.502339e-17
# 25   -1.213960 -0.159241 -0.022964 -0.129487 -0.024430 -0.000969  7.396152e-17
# 26   -1.062958 -0.089433 -0.248452 -0.136328 -0.047280  0.000652  5.100865e-17
# 27    0.241967 -0.129001  0.137323  0.080884  0.021558  0.007184 -4.809379e-17
# 28    0.258925 -0.140760  0.144069  0.075944 -0.011357  0.007396 -5.615446e-17
# 29    0.237362 -0.136690  0.141331  0.080391 -0.019545  0.006852 -5.161185e-17
# ...        ...       ...       ...       ...       ...       ...           ...
# 1072 -0.152540  0.165706 -0.172167  0.077077 -0.016919 -0.016363  7.901284e-17
# 1073 -0.538109 -0.245304 -0.136571  0.002301 -0.039569  0.013756  1.723426e-16
# 1074  0.329408 -0.113467 -0.125468  0.061640  0.100070  0.007984 -6.221210e-17
# 1075  0.721051  0.318357 -0.214185  0.097247 -0.069312  0.001338 -3.336718e-17
# 1076 -1.099467  0.160208  0.040373 -0.195642  0.016287 -0.002195  1.545480e-16
# 1077 -0.602945  0.075271  0.123729  0.024478 -0.061346 -0.002686 -8.762926e-17
# 1078 -0.667616 -0.251225 -0.107830  0.044851 -0.000696  0.016150  1.146982e-16
# 1079  0.071822  0.191584  0.157486  0.133314  0.062627 -0.003547 -4.010010e-17
# 1080 -1.166339 -0.252683 -0.139134  0.050269 -0.064375 -0.001669  8.451059e-17
# 1081  0.050910  0.164629 -0.196867  0.184971 -0.018177  0.000299 -3.899760e-17
# 1082 -0.270536 -0.354592 -0.059097  0.018251 -0.019806 -0.001033  4.365326e-17
# 1083 -0.266075 -0.031322  0.062674 -0.114501 -0.009917  0.009318  1.922278e-17
# 1084  0.622224 -0.038875 -0.158766 -0.034480  0.041000  0.002780  2.138846e-17
# 1085 -0.732056 -0.318192 -0.034804 -0.001310 -0.002782  0.010789  1.926385e-16
# 1086 -0.315665 -0.046166 -0.060558 -0.121075  0.087202  0.008213  2.960918e-17
# 1087 -0.661793 -0.236017  0.024119  0.048125 -0.120925  0.016434  1.024329e-16
# 1088  0.304935 -0.103664  0.072290 -0.065292 -0.017271 -0.001273  1.230583e-17
# 1089 -0.516900  0.087263  0.066011 -0.025671  0.020800 -0.008852  4.107126e-17
# 1090 -0.629495 -0.064601 -0.051584 -0.022231  0.005933  0.000368  2.056114e-17
# 1091 -0.061797 -0.207288  0.012150  0.021448 -0.045612  0.008374 -7.436297e-17
# 1092  0.272545  0.151524  0.136907  0.217730  0.043880 -0.017458 -6.992411e-17
# 1093  0.229128 -0.001941  0.099371 -0.031644 -0.052644 -0.002834 -1.057489e-16
# 1094 -0.335172  0.233970  0.183333  0.142376  0.049809 -0.005378  6.953037e-17
# 1095 -0.375503  0.288908  0.092285 -0.209331  0.024316 -0.005612  1.992079e-16
# 1096  0.577283 -0.057046  0.018530 -0.030879 -0.065730  0.002341  1.686417e-17
# 1097 -0.663975  0.141987 -0.044757  0.002241 -0.032147 -0.011901  3.942186e-18
# 1098  1.149373 -0.208890  0.119308  0.015256  0.039570  0.007198 -1.529291e-17
# 1099 -0.813045  0.111376 -0.203249  0.185651  0.042467 -0.019704 -2.137083e-16
# 1100 -0.135326  0.065686  0.141067  0.031440  0.002097  0.006835 -3.405558e-17
# 1101 -0.139869  0.023911  0.065197  0.025966  0.000073  0.006139 -3.435709e-17
#
# [1102 rows x 20 columns]

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = .25)

# %% [markdown]
# ## Random Forrest on Numerical Data

# %%
rf = RandomForestClassifier(n_jobs=4)
rf_params = {'n_estimators':[8,10,12,14,20],
            'min_samples_split':[2,3,4],
            'random_state':[1,21,31,100]}
rf_gs = GridSearchCV(rf, rf_params, n_jobs=4)
rf_gs.fit(X_train, y_train)
rf_gs.best_params_
# Out:
# {'min_samples_split': 4, 'n_estimators': 20, 'random_state': 31}

# %%
rf_preds = rf_gs.predict(X_test)

# %%
precision_score(y_test, rf_preds), accuracy_score(y_test, rf_preds)
# Out:
# (0.7651006711409396, 0.7318840579710145)

# %% [markdown]
# ## AdaBoost on Numerical Data

# %%
ada = AdaBoostClassifier()
ada_params = {'n_estimators':[30,40,50,60,80],
             'learning_rate':[.8,.4,.1],}
ada_gs = GridSearchCV(ada, ada_params, n_jobs=4)
ada_gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None),
#        fit_params=None, iid=True, n_jobs=4,
#        param_grid={'n_estimators': [30, 40, 50, 60, 80], 'learning_rate': [0.8, 0.4, 0.1]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
ada_preds = ada_gs.predict(X_test)

# %%
ada_gs.best_params_
# Out:
# {'learning_rate': 0.4, 'n_estimators': 60}

# %%
precision_score(y_test, preds), accuracy_score(y_test, preds)
# Out:
# (0.8181818181818182, 0.75)

# %% [markdown]
# ## Gradient Boost on Numerical Data

# %%
xgb = GradientBoostingClassifier()
xgb_params = {'learning_rate':[.01, .05, .1, .3, .5],
             'n_estimators':[50,80, 100, 120]}
xgb_gs = GridSearchCV(xgb, xgb_params, n_jobs=4)
xgb_gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False),
#        fit_params=None, iid=True, n_jobs=4,
#        param_grid={'learning_rate': [0.01, 0.05, 0.1, 0.3, 0.5], 'n_estimators': [50, 80, 100, 120]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
xgb_gs.best_params_
# Out:
# {'learning_rate': 0.3, 'n_estimators': 80}

# %%
xgb_preds = xgb_gs.predict(X_test)

# %%
precision_score(y_test, xgb_preds), accuracy_score(y_test, xgb_preds)
# Out:
# (0.7619047619047619, 0.7246376811594203)

# %% [markdown]
# ## Trying same three models on dummied data

# %%
dummies_df = pd.get_dummies(df)

# %%
X_dum = dummies_df.drop('WnvPresent', axis = 1)
y = dummies_df.WnvPresent

# %%
Xdum_train, Xdum_test, ydum_train, ydum_test = train_test_split(X_dum, y, test_size = .25)

# %% [markdown]
# ## Random Forrest on Dummy Data
# ### Random forest had highest accuracy of 78.6% but lower precision than AdaBoost using just numerical data

# %%
rf_dum = RandomForestClassifier(n_jobs=4)
rf_params = {'n_estimators':[8,10,12,14,20],
            'min_samples_split':[2,3,4],
            'random_state':[1,21,31,100]}
rf_dum_gs = GridSearchCV(rf_dum, rf_params, n_jobs=4)
rf_dum_gs.fit(Xdum_train, ydum_train)
rf_dum_gs.best_params_
# Out:
# {'min_samples_split': 2, 'n_estimators': 20, 'random_state': 31}

# %%
rf_dum_preds = rf_dum_gs.predict(Xdum_test)

# %%
precision_score(ydum_test, rf_dum_preds), accuracy_score(ydum_test, rf_dum_preds)
# Out:
# (0.7936507936507936, 0.7862318840579711)

# %% [markdown]
# ## AdaBoost on Dummy Data

# %%
ada_dum = AdaBoostClassifier()
ada_dum_params = {'n_estimators':[30,40,50,60,80],
             'learning_rate':[.8,.4,.1],}
ada_dum_gs = GridSearchCV(ada_dum, ada_params, n_jobs=4)
ada_dum_gs.fit(Xdum_train, ydum_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None),
#        fit_params=None, iid=True, n_jobs=4,
#        param_grid={'n_estimators': [30, 40, 50, 60, 80], 'learning_rate': [0.8, 0.4, 0.1]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
ada_dum_preds = ada_dum_gs.predict(Xdum_test)

# %%
ada_dum_gs.best_params_
# Out:
# {'learning_rate': 0.4, 'n_estimators': 40}

# %%
precision_score(ydum_test, ada_dum_preds), accuracy_score(ydum_test, ada_dum_preds)
# Out:
# (0.7622377622377622, 0.7898550724637681)

# %% [markdown]
# ## Gradient Boost on Dummy Data

# %%
xgb_dum = GradientBoostingClassifier()
xgb_dum_params = {'learning_rate':[.01, .05, .1, .3, .5],
             'n_estimators':[50,80, 100, 120]}
xgb_dum_gs = GridSearchCV(xgb_dum, xgb_dum_params, n_jobs=4)
xgb_dum_gs.fit(Xdum_train, ydum_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False),
#        fit_params=None, iid=True, n_jobs=4,
#        param_grid={'learning_rate': [0.01, 0.05, 0.1, 0.3, 0.5], 'n_estimators': [50, 80, 100, 120]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
xgb_dum_gs.best_params_
# Out:
# {'learning_rate': 0.05, 'n_estimators': 100}

# %%
xgb_dum_preds = xgb_dum_gs.predict(Xdum_test)

# %%
precision_score(ydum_test, xgb_dum_preds), accuracy_score(ydum_test, xgb_dum_preds)
# Out:
# (0.7551020408163265, 0.7898550724637681)
